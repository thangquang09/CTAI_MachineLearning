# %% [markdown]
# # Baseline Solution: Fake or Real - The Impostor Hunt in Texts 🔍
#
# ---
#
# Here we provide the baseline solution for the *Fake or Real: The Impostor Hunt in Texts* challenge!
# In this notebook, we walk you through two **simple, interpretable, and ML-free approaches** to tackle the problem of detecting fake texts.
#
# ### 💡 The overview of first approach:
#
# We use the `langdetect` library to analyze each text by identifying the presence of **English vs. non-English words**. Here's the idea:
#
# 1. **Detect Language**: We break the text into words and determine the language of each.
# 2. **Calculate Proportion**: We then compute the percentage of English words in the entire text.
# 3. **Assign Label**: The text which gets higher percentage of English words is classified as **Real** and its number is saved to the results list.
#
# ---
#
# ### 📦 Getting Started: Install & Import Required Packages

# %%
# !pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 4.6 MB/s eta 0:00:00m-:--:--
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /home/thangquang/anaconda3/lib/python3.13/site-packages (from langdetect) (1.17.0)
# Building wheels for collected packages: langdetect
#   DEPRECATION: Building 'langdetect' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'langdetect'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=6f6486e61971787709e7f5c4bbd55cee1297e11f810d3775007df2a0e86ed9e7
#   Stored in directory: /home/thangquang/.cache/pip/wheels/eb/87/25/2dddf1c94e1786054e25022ec5530bfed52bad86d882999c48
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
import os
import string
import unicodedata

import numpy as np
import pandas as pd
from langdetect import DetectorFactory, detect
from langdetect.lang_detect_exception import LangDetectException
from sklearn.metrics import accuracy_score

DetectorFactory.seed = 42


def read_texts_from_dir(dir_path):
    """
    Reads the texts from a given directory and saves them in the pd.DataFrame with columns ['id', 'file_1', 'file_2'].

    Params:
      dir_path (str): path to the directory with data
    """
    # Count number of directories in the provided path
    dir_count = sum(
        os.path.isdir(os.path.join(root, d))
        for root, dirs, _ in os.walk(dir_path)
        for d in dirs
    )
    data = [0 for _ in range(dir_count)]
    print(f"Number of directories: {dir_count}")

    # For each directory, read both file_1.txt and file_2.txt and save results to the list
    i = 0
    for folder_name in sorted(os.listdir(dir_path)):
        folder_path = os.path.join(dir_path, folder_name)
        if os.path.isdir(folder_path):
            try:
                with open(
                    os.path.join(folder_path, "file_1.txt"), "r", encoding="utf-8"
                ) as f1:
                    text1 = f1.read().strip()
                with open(
                    os.path.join(folder_path, "file_2.txt"), "r", encoding="utf-8"
                ) as f2:
                    text2 = f2.read().strip()
                index = int(folder_name[-4:])
                data[i] = (index, text1, text2)
                i += 1
            except Exception as e:
                print(f"Error reading directory {folder_name}: {e}")

    # Change list with results into pandas DataFrame
    df = pd.DataFrame(data, columns=["id", "file_1", "file_2"]).set_index("id")
    return df


# =================== LOAD DATA ================================

# Use the above function to load both train and test data
# train_path="/kaggle/input/fake-or-real-the-impostor-hunt/data/train"
# df_train=read_texts_from_dir(train_path)
# test_path="/kaggle/input/fake-or-real-the-impostor-hunt/data/test"
# df_test=read_texts_from_dir(test_path)


# Use the above function to load both train and test data
train_path = "/home/thangquang/CODE/CTAI_MachineLearning/data/fake-or-real-the-impostor-hunt/data/train"
df_train = read_texts_from_dir(train_path)
test_path = "/home/thangquang/CODE/CTAI_MachineLearning/data/fake-or-real-the-impostor-hunt/data/test"
df_test = read_texts_from_dir(test_path)

# Load ground truth for train data
df_train_gt = pd.read_csv(
    "/home/thangquang/CODE/CTAI_MachineLearning/data/fake-or-real-the-impostor-hunt/data/train.csv"
)
# df_train_gt
# Out:
# Number of directories: 95
# Number of directories: 1068

# %%
# ----------------------------- 1. IMPORTS ------------------------------------
import os, re, gc, warnings, random
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# ML & utils
from sklearn.model_selection import StratifiedKFold, GridSearchCV, train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from scipy.sparse import hstack, csr_matrix

warnings.filterwarnings("ignore")
nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('stopwords', quiet=True)

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# ----------------------- 2. TEXT PRE-PROCESSING ------------------------------
lemmatizer = WordNetLemmatizer()
stop_words  = set(stopwords.words("english"))

def clean_text(text: str) -> str:
    """Làm sạch + chuẩn hoá một câu văn."""
    if not isinstance(text, str):
        return ""
    
    text = re.sub(r"http\S+", " ", text)          # xoá URL
    text = re.sub(r"\d+", " NUM ", text)          # thay số = token NUM
    text = re.sub(r"[^\w\s]", " ", text)          # bỏ punctuation
    text = text.lower()
    tokens = [lemmatizer.lemmatize(tok)
              for tok in word_tokenize(text)
              if tok.isalpha() and tok not in stop_words and len(tok) > 2]
    return " ".join(tokens)

def preprocess_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    """Áp dụng clean_text cho 2 cột file_1 và file_2 + tạo cột combined."""
    tqdm.pandas(desc="Cleaning text")
    df["file_1"] = df["file_1"].progress_apply(clean_text)
    df["file_2"] = df["file_2"].progress_apply(clean_text)
    df["combined"] = df["file_1"] + " [SEP] " + df["file_2"]
    return df

# ----------------------- 3. STATISTICAL FEATURES -----------------------------
def statistical_features(df: pd.DataFrame) -> np.ndarray:
    """Sinh đặc trưng thống kê/đếm đơn giản ở dạng dense numpy array."""
    len_1   = df["file_1"].str.len()
    len_2   = df["file_2"].str.len()
    words_1 = df["file_1"].str.split().apply(len)
    words_2 = df["file_2"].str.split().apply(len)

    features = pd.DataFrame({
        "len_diff"       : (len_1 - len_2).abs(),
        "word_diff"      : (words_1 - words_2).abs(),
        "len_ratio"      : (len_1 + 1) / (len_2 + 1),
        "words_ratio"    : (words_1 + 1) / (words_2 + 1),
        "avg_word_len_1" : df["file_1"].apply(lambda x: np.mean([len(w) for w in x.split()]) if x else 0),
        "avg_word_len_2" : df["file_2"].apply(lambda x: np.mean([len(w) for w in x.split()]) if x else 0),
    })
    return features.values.astype(np.float32)

# ----------------------- 4. VECTORIZERS --------------------------------------
word_vectorizer = TfidfVectorizer(
    ngram_range=(1, 3),
    analyzer="word",
    max_features=20_000,
    sublinear_tf=True,
)

char_vectorizer = TfidfVectorizer(
    ngram_range=(3, 6),
    analyzer="char_wb",
    max_features=15_000,
    sublinear_tf=True,
)

# ----------------------- 5. MODEL + PIPELINE ---------------------------------
def build_feature_matrix(df: pd.DataFrame, fit: bool = False):
    """Trả về sparse matrix = [word_tfidf | char_tfidf | stats_dense]."""
    # TF-IDF
    if fit:
        X_word = word_vectorizer.fit_transform(df["combined"])
        X_char = char_vectorizer.fit_transform(df["combined"])
    else:
        X_word = word_vectorizer.transform(df["combined"])
        X_char = char_vectorizer.transform(df["combined"])

    # Statistical (dense) -> convert to sparse for hstack
    X_stats = csr_matrix(statistical_features(df))

    return hstack([X_word, X_char, X_stats]).tocsr()

def train_and_evaluate(X, y, clf_model, param_grid):
    """Cross-validate + grid search LogisticRegression, trả về best model."""
    # Feature selection bên trong pipeline để không rò rỉ dữ liệu
    clf = Pipeline([
        ("select", SelectKBest(chi2, k=20_000)),
        ("clf", clf_model)
    ])

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
    grid = GridSearchCV(
        estimator=clf,
        param_grid=param_grid,
        scoring="accuracy",
        cv=skf,
        n_jobs=-1,
        verbose=2
    )
    grid.fit(X, y)
    print(f"Best CV accuracy: {grid.best_score_:.4f}")
    print(f"Best params    : {grid.best_params_}")
    return grid.best_estimator_




# ===================================================
print("Pre-processing train ...")
df_train = preprocess_dataframe(df_train)
print("Pre-processing test  ...")
df_test  = preprocess_dataframe(df_test)

# --- 6.2 Build feature matrices -----------------------------------------
print("Vectorizing & building features ...")
X_train = build_feature_matrix(df_train, fit=True)
X_test  = build_feature_matrix(df_test,  fit=False)
y_train = df_train_gt["real_text_id"].values  # 0 hoặc 1
# Out:
# Pre-processing train ...
# Cleaning text:   0%|          | 0/95 [00:00<?, ?it/s]
# Cleaning text:   0%|          | 0/95 [00:00<?, ?it/s]
# Pre-processing test  ...
# Cleaning text:   0%|          | 0/1068 [00:00<?, ?it/s]
# Cleaning text:   0%|          | 0/1068 [00:00<?, ?it/s]
# Vectorizing & building features ...

# %% [markdown]
# #### Logistic Regression

# %%
clf_model = LogisticRegression(max_iter=5_000, solver="liblinear", n_jobs=-1)
param_grid = {
        "select__k"   : [15_000, 20_000, 25_000],
        "clf__C"      : [0.1, 0.5, 1, 2, 5],
        "clf__penalty": ["l1", "l2"]
    }

# %%
# --- 6.3 Train + CV ------------------------------------------------------
model = train_and_evaluate(X_train, y_train, clf_model, param_grid)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=15000; total time=   0.4s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=15000; total time=   0.6s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=15000; total time=   0.9s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=15000; total time=   1.0s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=20000; total time=   1.0s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=15000; total time=   1.0s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=25000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=25000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=25000; total time=   0.2s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=20000; total time=   1.1s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=25000; total time=   0.2s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=25000; total time=   0.2s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=25000; total time=   1.3s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=15000; total time=   0.3s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=20000; total time=   1.4s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=20000; total time=   1.3s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=15000; total time=   0.5s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=20000; total time=   0.5s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=25000; total time=   2.1s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=20000; total time=   0.8s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=25000; total time=   0.7s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=15000; total time=   1.5s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=25000; total time=   3.1s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=20000; total time=   0.2s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=20000; total time=   0.2s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=25000; total time=   3.3s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=15000; total time=   2.0s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=25000; total time=   0.1s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=25000; total time=   0.2s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=20000; total time=   3.4s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=25000; total time=   0.2s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=15000; total time=   0.3s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=25000; total time=   0.6s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=25000; total time=   2.1s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=15000; total time=   0.3s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=20000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=15000; total time=   2.9s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=15000; total time=   1.1s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=25000; total time=   2.3s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=25000; total time=   0.7s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=20000; total time=   1.2s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=25000; total time=   5.0s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=15000; total time=   2.2s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=15000; total time=   0.2s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=20000; total time=   4.3s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=25000; total time=   1.2s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=20000; total time=   0.2s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=25000; total time=   0.2s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=25000; total time=   0.3s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=15000; total time=   0.4s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=25000; total time=   0.6s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=25000; total time=   0.6s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=15000; total time=   0.5s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=20000; total time=   6.0s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=20000; total time=   0.6s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=20000; total time=   3.6s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=15000; total time=   4.1s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=25000; total time=   0.8s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=25000; total time=   4.3s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=20000; total time=   4.7s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=20000; total time=   1.0s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=15000; total time=   2.3s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=20000; total time=   7.6s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=15000; total time=   2.8s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=25000; total time=   7.4s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=15000; total time=   0.2s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=15000; total time=   0.2s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=20000; total time=   0.2s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=25000; total time=   0.2s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=25000; total time=   0.3s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=25000; total time=   0.5s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=25000; total time=   0.5s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=25000; total time=   5.6s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=15000; total time=   0.4s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=25000; total time=   2.2s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=15000; total time=   4.4s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=15000; total time=   1.2s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=20000; total time=   1.2s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=15000; total time=   2.2s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=20000; total time=   4.9s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=15000; total time=   2.2s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=25000; total time=  10.8s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=20000; total time=   1.3s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=20000; total time=   6.2s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=25000; total time=   5.2s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=20000; total time=  10.1s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=20000; total time=   0.2s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=20000; total time=   0.2s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=25000; total time=   0.1s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=20000; total time=   0.2s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=25000; total time=   0.3s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=25000; total time=   2.5s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=25000; total time=   0.2s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=15000; total time=   5.5s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=20000; total time=   4.1s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=25000; total time=   4.4s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=25000; total time=  12.2s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=25000; total time=   8.3s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=25000; total time=   4.0s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=20000; total time=   9.6s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=20000; total time=   6.8s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=20000; total time=   7.0s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=25000; total time=   5.3s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=25000; total time=   9.9s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=25000; total time=   7.0s
# Best CV accuracy: 0.7263
# Best params    : {'clf__C': 5, 'clf__penalty': 'l1', 'select__k': 15000}

# %%
from sklearn.ensemble import RandomForestClassifier

clf_model = RandomForestClassifier(random_state=SEED, n_jobs=-1)
param_grid = {
    "select__k": [15_000, 20_000, 25_000],
    "clf__n_estimators": [300, 500, 1000, 1500],
    "clf__max_depth": [None, 10, 20, 30],
    "clf__min_samples_split": [2, 5, 10],
    "clf__min_samples_leaf": [1, 2, 4]
}

# %%
# --- 6.3 Train + CV ------------------------------------------------------
rf_model = train_and_evaluate(X_train, y_train, clf_model, param_grid)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=15000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=20000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=20000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=25000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=15000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=20000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=25000; total time=   1.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=25000; total time=   1.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300, select__k=25000; total time=   1.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=20000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=25000; total time=   1.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=25000; total time=   1.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=25000; total time=   1.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=20000; total time=   1.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=500, select__k=20000; total time=   2.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=15000; total time=   2.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=15000; total time=   2.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=15000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=15000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=20000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=20000; total time=   3.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=20000; total time=   3.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=25000; total time=   3.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=25000; total time=   3.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=25000; total time=   3.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=25000; total time=   3.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=25000; total time=   3.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1000, select__k=20000; total time=   3.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=15000; total time=   4.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=15000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=15000; total time=   4.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=15000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=15000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=15000; total time=   4.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=20000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=15000; total time=   4.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=20000; total time=   4.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=20000; total time=   4.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=20000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=20000; total time=   4.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=20000; total time=   4.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   5.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   0.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   0.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   0.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   3.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   0.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   3.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=15000; total time=   4.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=15000; total time=   0.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=15000; total time=   4.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=15000; total time=   4.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=15000; total time=   0.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=15000; total time=   4.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=20000; total time=   3.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=15000; total time=   4.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=20000; total time=   4.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=20000; total time=   4.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=20000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=20000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=25000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=25000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=20000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=25000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=25000; total time=   4.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=25000; total time=   4.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=25000; total time=   4.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300, select__k=25000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=10, clf__n_estimators=1500, select__k=25000; total time=   4.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=15000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=25000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=15000; total time=   2.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=15000; total time=   2.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=15000; total time=   2.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=20000; total time=   2.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=15000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=20000; total time=   3.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=25000; total time=   3.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=25000; total time=   3.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=25000; total time=   3.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1000, select__k=25000; total time=   3.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=15000; total time=   3.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=15000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=15000; total time=   4.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=15000; total time=   3.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=15000; total time=   0.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=15000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=20000; total time=   0.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=15000; total time=   4.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=20000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=20000; total time=   4.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=20000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=20000; total time=   4.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=20000; total time=   4.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.3s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   3.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   1.2s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.8s[CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.7s
#
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.1s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.5s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.6s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.7s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   2.8s
# ...
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.7s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=1500, select__k=25000; total time=   4.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.3s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=20000; total time=   1.7s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.7s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=500, select__k=25000; total time=   1.7s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   2.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=15000; total time=   3.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   3.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   3.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=20000; total time=   3.1s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.1s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1000, select__k=25000; total time=   3.2s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   3.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   0.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   1.2s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.1s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   3.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.3s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=15000; total time=   4.2s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=15000; total time=   0.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.3s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.4s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   0.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   1.1s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=20000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.4s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=20000; total time=   4.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.7s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=1500, select__k=25000; total time=   4.7s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=300, select__k=25000; total time=   1.1s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.3s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.4s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.3s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=15000; total time=   1.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.4s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=20000; total time=   1.7s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=500, select__k=25000; total time=   1.7s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.5s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=15000; total time=   2.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.7s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   3.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=20000; total time=   2.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   2.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   2.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   2.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1000, select__k=25000; total time=   3.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=15000; total time=   3.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=15000; total time=   3.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=15000; total time=   4.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=15000; total time=   3.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=20000; total time=   3.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=15000; total time=   4.2s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=20000; total time=   3.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=20000; total time=   3.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=20000; total time=   4.0s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=20000; total time=   3.9s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=25000; total time=   3.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=25000; total time=   3.7s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=25000; total time=   3.8s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=25000; total time=   3.6s
# [CV] END clf__max_depth=30, clf__min_samples_leaf=4, clf__min_samples_split=10, clf__n_estimators=1500, select__k=25000; total time=   3.5s
# Best CV accuracy: 0.6421
# Best params    : {'clf__max_depth': None, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 5, 'clf__n_estimators': 500, 'select__k': 15000}

# %%
# --- 6.5 Retrain on full data & infer test -------------------------------
print("Training on full data ...")
model.fit(X_train, y_train)

print("Predicting on test ...")
test_pred = model.predict(X_test)

# --- 6.6 Build submission -------------------------------------------------
submission = pd.DataFrame({
    "id": df_test.index,
    "real_text_id": test_pred.astype(int)
}).sort_values("id")

save_path = Path("submission.csv")
submission.to_csv(save_path, index=False)
print(f"✅  Submission saved to {save_path.resolve()}")

# %%
# ----------------------------- 1. IMPORTS ------------------------------------
import os, re, gc, warnings, random
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm
from collections import Counter

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize

# ML & utils
from sklearn.model_selection import StratifiedKFold, GridSearchCV, train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest, chi2, f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from scipy.sparse import hstack, csr_matrix

warnings.filterwarnings("ignore")
nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('stopwords', quiet=True)

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# ----------------------- 2. TEXT PRE-PROCESSING ------------------------------
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))

def clean_text(text: str) -> str:
    """Làm sạch + chuẩn hoá một câu văn."""
    if not isinstance(text, str):
        return ""
    
    text = re.sub(r"http\S+", " ", text)  # xoá URL
    text = re.sub(r"\d+", " NUM ", text)  # thay số = token NUM
    text = re.sub(r"[^\w\s]", " ", text)  # bỏ punctuation
    text = text.lower()
    tokens = [lemmatizer.lemmatize(tok)
              for tok in word_tokenize(text)
              if tok.isalpha() and tok not in stop_words and len(tok) > 2]
    return " ".join(tokens)

def preprocess_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    """Áp dụng clean_text cho 2 cột file_1 và file_2 + tạo cột combined."""
    tqdm.pandas(desc="Cleaning text")
    df["file_1"] = df["file_1"].progress_apply(clean_text)
    df["file_2"] = df["file_2"].progress_apply(clean_text)
    df["combined"] = df["file_1"] + " [SEP] " + df["file_2"]
    return df

# ----------------------- 3. RULE-BASED FEATURES ------------------------------
def compute_rule_based_features(text: str) -> dict:
    """Tính toán các đặc trưng rule-based cho một văn bản."""
    if not isinstance(text, str):
        text = ""
    
    # Độ dài và cấu trúc
    char_count = len(text)
    word_count = len(word_tokenize(text))
    sentence_count = len(sent_tokenize(text))
    avg_sentence_length = word_count / max(sentence_count, 1)
    
    # Tính trang trọng: Số liệu, đơn vị, từ viết tắt
    number_count = len(re.findall(r'\d+', text))
    unit_count = len(re.findall(r'\b(?:km|cm|m|s|kg|g|Hz|K|A|deg|arcsec|dex|A|petabytes|terabytes)\b', text, re.I))
    acronym_count = len(re.findall(r'\b[A-Z]{2,}\b', text))
    uppercase_word_count = len(re.findall(r'\b[A-Z][A-Z]+\b', text))
    
    # Dấu chấm than và giọng văn không trang trọng
    exclamation_count = text.count('!')
    
    # Lặp từ (repetition)
    words = word_tokenize(text.lower())
    repetition_score = sum([count for word, count in Counter(words).items() if count > 3]) / max(word_count, 1)
    
    # Từ khóa bất thường (dấu hiệu FAKE)
    china_count = text.lower().count('china')
    dinosaur_count = text.lower().count('dinosaur')
    
    return {
        'char_count': char_count,
        'word_count': word_count,
        'sentence_count': sentence_count,
        'avg_sentence_length': avg_sentence_length,
        'number_count': number_count,
        'unit_count': unit_count,
        'acronym_count': acronym_count,
        'uppercase_word_count': uppercase_word_count,
        'exclamation_count': exclamation_count,
        'repetition_score': repetition_score,
        'china_count': china_count,
        'dinosaur_count': dinosaur_count
    }

def extract_rule_based_features(df: pd.DataFrame) -> np.ndarray:
    """Tạo ma trận đặc trưng rule-based, bao gồm diff giữa file_1 và file_2."""
    features = []
    for _, row in tqdm(df.iterrows(), total=len(df), desc="Extracting rule-based features"):
        f1 = compute_rule_based_features(row['file_1'])
        f2 = compute_rule_based_features(row['file_2'])
        
        # Tạo diff features
        diff = {k: f1[k] - f2[k] for k in f1}
        
        # Kết hợp f1, f2, diff thành một vector
        feature_vector = list(f1.values()) + list(f2.values()) + list(diff.values())
        features.append(feature_vector)
    
    return np.array(features).astype(np.float32)

# ----------------------- 4. STATISTICAL FEATURES -----------------------------
def statistical_features(df: pd.DataFrame) -> np.ndarray:
    """Sinh đặc trưng thống kê/đếm đơn giản ở dạng dense numpy array."""
    len_1 = df["file_1"].str.len()
    len_2 = df["file_2"].str.len()
    words_1 = df["file_1"].str.split().apply(len)
    words_2 = df["file_2"].str.split().apply(len)

    features = pd.DataFrame({
        "len_diff": (len_1 - len_2).abs(),
        "word_diff": (words_1 - words_2).abs(),
        "len_ratio": (len_1 + 1) / (len_2 + 1),
        "words_ratio": (words_1 + 1) / (words_2 + 1),
        "avg_word_len_1": df["file_1"].apply(lambda x: np.mean([len(w) for w in x.split()]) if x else 0),
        "avg_word_len_2": df["file_2"].apply(lambda x: np.mean([len(w) for w in x.split()]) if x else 0),
    })
    return features.values.astype(np.float32)

# ----------------------- 5. VECTORIZERS --------------------------------------
word_vectorizer = TfidfVectorizer(
    ngram_range=(1, 3),
    analyzer="word",
    max_features=20_000,
    sublinear_tf=True,
)

char_vectorizer = TfidfVectorizer(
    ngram_range=(3, 6),
    analyzer="char_wb",
    max_features=15_000,
    sublinear_tf=True,
)

# ----------------------- 6. BUILD FEATURE MATRIX -----------------------------
def build_feature_matrix(df: pd.DataFrame, fit: bool = False):
    """Trả về sparse matrix = [word_tfidf | char_tfidf | rule_based_dense | stats_dense]."""
    # TF-IDF
    if fit:
        X_word = word_vectorizer.fit_transform(df["combined"])
        X_char = char_vectorizer.fit_transform(df["combined"])
    else:
        X_word = word_vectorizer.transform(df["combined"])
        X_char = char_vectorizer.transform(df["combined"])

    # Rule-based (dense) -> convert to sparse
    X_rule = csr_matrix(extract_rule_based_features(df))

    # Statistical (dense) -> convert to sparse
    X_stats = csr_matrix(statistical_features(df))

    return hstack([X_word, X_char, X_rule, X_stats]).tocsr()

# ----------------------- 7. MODEL + PIPELINE ---------------------------------
def train_and_evaluate(X, y, clf_model, param_grid):
    """Cross-validate + grid search, trả về best model."""
    clf = Pipeline([
        ("select", SelectKBest(f_classif, k=20_000)),  # Use f_classif instead of chi2
        ("clf", clf_model)
    ])

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
    grid = GridSearchCV(
        estimator=clf,
        param_grid=param_grid,
        scoring="accuracy",
        cv=skf,
        n_jobs=-1,
        verbose=2
    )
    grid.fit(X, y)
    print(f"Best CV accuracy: {grid.best_score_:.4f}")
    print(f"Best params : {grid.best_params_}")
    return grid.best_estimator_

# ===================================================
# Load data (thay đổi path nếu cần)
train_path = "/home/thangquang/CODE/CTAI_MachineLearning/data/fake-or-real-the-impostor-hunt/data/train"
df_train = read_texts_from_dir(train_path)
test_path = "/home/thangquang/CODE/CTAI_MachineLearning/data/fake-or-real-the-impostor-hunt/data/test"
df_test = read_texts_from_dir(test_path)

# Load ground truth
df_train_gt = pd.read_csv(
    "/home/thangquang/CODE/CTAI_MachineLearning/data/fake-or-real-the-impostor-hunt/data/train.csv"
)
y_train = df_train_gt["real_text_id"].values  # 0 hoặc 1

print("Pre-processing train ...")
df_train = preprocess_dataframe(df_train)
print("Pre-processing test ...")
df_test = preprocess_dataframe(df_test)

print("Vectorizing & building features ...")
X_train = build_feature_matrix(df_train, fit=True)
X_test = build_feature_matrix(df_test, fit=False)
# Out:
# Number of directories: 95
# Number of directories: 1068
# Pre-processing train ...
# Cleaning text:   0%|          | 0/95 [00:00<?, ?it/s]
# Cleaning text:   0%|          | 0/95 [00:00<?, ?it/s]
# Pre-processing test ...
# Cleaning text:   0%|          | 0/1068 [00:00<?, ?it/s]
# Cleaning text:   0%|          | 0/1068 [00:00<?, ?it/s]
# Vectorizing & building features ...
# Extracting rule-based features:   0%|          | 0/95 [00:00<?, ?it/s]
# Extracting rule-based features:   0%|          | 0/1068 [00:00<?, ?it/s]

# %%
# Lưu X_train, X_test, y_train
import joblib

joblib.dump(X_train, "X_train.pkl")
joblib.dump(X_test, "X_test.pkl")
joblib.dump(y_train, "y_train.pkl")
# Out:
# ['y_train.pkl']

# %%
# #### Logistic Regression
clf_model = LogisticRegression(max_iter=5_000, solver="liblinear", n_jobs=-1)
param_grid = {
    "select__k": [15_000, 20_000, 25_000],
    "clf__C": [0.1, 0.5, 1, 2, 5],
    "clf__penalty": ["l1", "l2"]
}

# --- Train + CV ------------------------------------------------------
model = train_and_evaluate(X_train, y_train, clf_model, param_grid)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=15000; total time=   0.2s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=20000; total time=   0.3s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=15000; total time=   0.3s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=20000; total time=   0.5s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=15000; total time=   0.2s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=20000; total time=   0.5s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=20000; total time=   0.1s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=15000; total time=   0.5s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=20000; total time=   0.6s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=15000; total time=   0.6s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=15000; total time=   0.3s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=25000; total time=   0.6s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=25000; total time=   0.7s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=15000; total time=   0.7s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=25000; total time=   0.7s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=15000; total time=   0.2s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=20000; total time=   0.4s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=20000; total time=   0.9s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=15000; total time=   0.8s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=25000; total time=   0.9s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=20000; total time=   0.4s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=25000; total time=   0.5s
# [CV] END .......clf__C=0.1, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=15000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=15000; total time=   0.4s
# [CV] END .......clf__C=0.1, clf__penalty=l1, select__k=25000; total time=   1.3s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=20000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=15000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=20000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=25000; total time=   0.6s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=15000; total time=   0.2s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=15000; total time=   0.3s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=25000; total time=   0.7s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=25000; total time=   0.5s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=15000; total time=   0.3s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=20000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=25000; total time=   0.7s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=15000; total time=   1.1s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=20000; total time=   1.0s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=20000; total time=   0.6s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=15000; total time=   0.9s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=15000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=25000; total time=   0.3s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=15000; total time=   1.4s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=25000; total time=   1.2s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=20000; total time=   0.5s
# [CV] END .......clf__C=0.5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=15000; total time=   0.3s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=15000; total time=   0.4s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=25000; total time=   0.8s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=20000; total time=   1.6s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=25000; total time=   0.6s[CV] END .........clf__C=1, clf__penalty=l2, select__k=15000; total time=   0.1s
#
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=25000; total time=   1.2s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=20000; total time=   0.6s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=15000; total time=   0.3s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=25000; total time=   1.0s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=25000; total time=   0.5s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=15000; total time=   1.5s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=25000; total time=   0.5s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=20000; total time=   0.5s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=15000; total time=   0.4s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=15000; total time=   0.5s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=20000; total time=   0.7s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=25000; total time=   0.2s
# [CV] END .......clf__C=0.5, clf__penalty=l1, select__k=20000; total time=   1.0s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=20000; total time=   1.8s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=25000; total time=   0.6s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=20000; total time=   1.8s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=15000; total time=   1.9s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=20000; total time=   0.6s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=15000; total time=   1.7s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=15000; total time=   0.3s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=15000; total time=   0.2s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=25000; total time=   0.6s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=25000; total time=   2.1s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=15000; total time=   0.2s
# [CV] END .........clf__C=1, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=20000; total time=   0.2s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=20000; total time=   0.8s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=25000; total time=   0.3s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=15000; total time=   1.7s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=25000; total time=   0.6s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=25000; total time=   2.4s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=15000; total time=   0.4s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=25000; total time=   1.5s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=15000; total time=   2.1s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=25000; total time=   2.4s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=25000; total time=   0.4s
# [CV] END .........clf__C=1, clf__penalty=l1, select__k=20000; total time=   1.8s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=20000; total time=   2.1s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=20000; total time=   0.4s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=15000; total time=   2.4s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=20000; total time=   2.5s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=15000; total time=   1.7s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=20000; total time=   0.8s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=25000; total time=   2.7s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=25000; total time=   1.7s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=20000; total time=   1.8s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=15000; total time=   0.1s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=15000; total time=   1.8s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=25000; total time=   3.3s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=15000; total time=   0.3s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=20000; total time=   0.2s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=15000; total time=   0.4s
# [CV] END .........clf__C=2, clf__penalty=l2, select__k=15000; total time=   0.2s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=15000; total time=   0.4s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=20000; total time=   0.3s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=20000; total time=   0.4s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=15000; total time=   2.7s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=20000; total time=   0.4s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=20000; total time=   0.7s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=25000; total time=   0.7s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=25000; total time=   0.6s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=25000; total time=   0.6s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=25000; total time=   0.5s
# [CV] END .........clf__C=5, clf__penalty=l2, select__k=25000; total time=   0.5s
# [CV] END .........clf__C=2, clf__penalty=l1, select__k=20000; total time=   2.6s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=25000; total time=   3.1s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=25000; total time=   3.0s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=20000; total time=   3.6s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=15000; total time=   2.4s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=20000; total time=   3.6s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=25000; total time=   2.9s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=20000; total time=   1.2s
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=20000; total time=   0.2s[CV] END .........clf__C=5, clf__penalty=l1, select__k=25000; total time=   3.4s
#
# [CV] END .........clf__C=5, clf__penalty=l1, select__k=25000; total time=   3.3s
# Best CV accuracy: 0.8316
# Best params : {'clf__C': 5, 'clf__penalty': 'l1', 'select__k': 15000}

# %%
# --- Retrain on full data & infer test -------------------------------
print("Training on full data ...")
model.fit(X_train, y_train)

print("Predicting on test ...")
test_pred = model.predict(X_test)

# --- Build submission -------------------------------------------------
submission = pd.DataFrame({
    "id": df_test.index,
    "real_text_id": test_pred.astype(int)
}).sort_values("id")

save_path = Path("submission.csv")
submission.to_csv(save_path, index=False)
print(f"✅ Submission saved to {save_path.resolve()}")
# Out:
# Training on full data ...
# Predicting on test ...
# ✅ Submission saved to /home/thangquang/CODE/CTAI_MachineLearning/notebooks/submission.csv
